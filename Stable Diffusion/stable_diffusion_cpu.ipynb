# %%
# !pip install --upgrade diffusers
# !pip3 install transformers
#conda install -c conda-forge diffusers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from diffusers import StableDiffusionPipeline

# %%
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", low_cpu_mem_usage=False).to('cpu')
# Out:
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]

# %%
prompt = input(prompt='What would you like to create?')
image = pipe([prompt])
# Out:
# What would you like to create?viking riding a scooter
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
if image['nsfw_content_detected'][0]:
  _ = image['images'].pop(0)
  del _
  image = 'The prompt returned NSFW content, please try another'
else:
  image = image['images'][0]
  
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FAB498EBE20>
